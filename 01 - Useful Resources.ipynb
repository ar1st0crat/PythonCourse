# %% [markdown]
# ### Пожалуй, лучший руcскоязычный видеокурс о Python
# https://www.youtube.com/playlist?list=PLlb7e2G7aSpTTNp7HBYzCBByaE1h54ruW

# %%
# видео одной из лекций
from IPython.display import YouTubeVideo
YouTubeVideo('vne1p3huhew')

# %% [markdown]
# ### Python: вещи, которых вы могли не знать
#
# https://habrahabr.ru/post/207988/

# %% [markdown]
# ### Buggy Python Code: The 10 Most Common Mistakes That Python Developers Make
# https://www.toptal.com/python/top-10-mistakes-that-python-programmers-make
# <img src='https://assets.toptal.io/uploads/blog/image/391/toptal-blog-image-1399578614447.png' width='400' />

# %% [markdown]
# ### Automate the Boring Stuff with Python
# https://automatetheboringstuff.com/
# ![](https://automatetheboringstuff.com/images/automate_cover_medium.png)

# %% [markdown]
# ### The Hitchhiker’s Guide to Python!
# http://docs.python-guide.org/en/latest/
# <img src='http://docs.python-guide.org/en/latest/_static/python-guide-logo.png' width='200' />

# %% [markdown]
# ### Python Challenge: The first programming riddle on the net
# Оригинально и может затянуть
# http://www.pythonchallenge.com/
# ![](http://www.pythonchallenge.com/logo.jpg)

# %% [markdown]
# ### ...А также великое множество IPython и Jupyter тетрадей в сети...
